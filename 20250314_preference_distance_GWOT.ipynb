# %%
from utilityFunctions import load_csv_to_matrix_batch, compute_color_preference_distance_batch, show_heatmaps, compute_color_similarity_distance_batch, compute_correlations, RSA, split_and_average_matrices
from utilityFunctions_GWOT import compute_GWOT_for_all_pairs
import numpy as np
import pickle
import os

# %%
unique_colours = np.array(['#d2b700', '#db8b08', '#c7512c', '#c13547', '#a03663', '#753a7a', '#4b488e', '#005692', '#006a8b', '#007b75', '#008a52', '#9aa400'])
colour_index = {colour: idx for idx, colour in enumerate(unique_colours)}
matrix_size = len(unique_colours)
response_type = 'similarity'

# %%
folder_path = 'raw_data/202411_data'
subject_matrices_similarity_raw = load_csv_to_matrix_batch(folder_path, response_type, colour_index, matrix_size)
subject_matrices_similarity_distance = compute_color_similarity_distance_batch(subject_matrices_similarity_raw)

# %%
# grouping_averaged_allcombination_similarity_distance = split_and_average_matrices(subject_matrices_similarity_distance)

# %%
filename = "list_average_of_all_possible_splitting.pkl"

# %%
# with open("list_average_of_all_possible_splitting.pkl", "wb") as file:
#     pickle.dump(grouping_averaged_allcombination_similarity_distance, file)
# print(f"Results successfully saved")

# %%
if os.path.exists(filename):
    with open(filename, "rb") as file:
        grouping_averaged_allcombination_similarity_distance = pickle.load(file)
    print("Results successfully loaded.")
else:
    print(f"Error: The file '{filename}' does not exist.")
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[4], line 5
#       3 if os.path.exists(filename):
#       4     with open(filename, "rb") as file:
# ----> 5         grouping_averaged_allcombination_similarity_distance = pickle.load(file)
#       6     print("Results successfully loaded.")
#       7 else:
#
# EOFError: Ran out of input

# %%
print(type(grouping_averaged_allcombination_similarity_distance))
print(len(grouping_averaged_allcombination_similarity_distance))
print(len(grouping_averaged_allcombination_similarity_distance[0]))
print(type(grouping_averaged_allcombination_similarity_distance[0][0]))
# Out:
# <class 'list'>
# 923780
# 2
# <class 'numpy.ndarray'>

# %%
### configuration
n_eps = 15 # number of epsilon values tried
eps_range = [0.04, 5] # the range of epsilon searched
epsilons = np.logspace(np.log10(eps_range[0]), np.log10(eps_range[1]), n_eps) # epsilon values

# %%
compute_GWOT_for_all_pairs(grouping_averaged_allcombination_similarity_distance, epsilons, save_filename="preference_distance_gwot_results.pkl")
# Out:
# Processing matrix pair 1/923780...
# /opt/anaconda3/envs/colorpreferencequalia/lib/python3.12/site-packages/ot/bregman/_sinkhorn.py:531: UserWarning: Sinkhorn did not converge. You might want to increase the number of iterations `numItermax` or the regularization parameter `reg`.
#   warnings.warn("Sinkhorn did not converge. You might want to "
# Best epsilon: 0.8914019321842716, Minimum GWD: 0.694
# Processing matrix pair 2/923780...
# Best epsilon: 0.31676392175331586, Minimum GWD: 0.988
# Processing matrix pair 3/923780...
# Best epsilon: 0.6313850355589193, Minimum GWD: 0.485
# Processing matrix pair 4/923780...
# Best epsilon: 0.6313850355589193, Minimum GWD: 0.479
# Processing matrix pair 5/923780...
# Best epsilon: 1.2584989506418272, Minimum GWD: 0.841
# Processing matrix pair 6/923780...
# Best epsilon: 0.8914019321842716, Minimum GWD: 0.723
# Processing matrix pair 7/923780...
# Best epsilon: 1.2584989506418272, Minimum GWD: 0.854
# Processing matrix pair 8/923780...
# Best epsilon: 0.8914019321842716, Minimum GWD: 0.865
# Processing matrix pair 9/923780...
# Best epsilon: 0.8914019321842716, Minimum GWD: 0.671
# Processing matrix pair 10/923780...
# Best epsilon: 0.6313850355589193, Minimum GWD: 0.589
# Processing matrix pair 11/923780...
# Best epsilon: 0.15891948094037048, Minimum GWD: 0.969
# Processing matrix pair 12/923780...
# Best epsilon: 0.6313850355589193, Minimum GWD: 0.706
# Processing matrix pair 13/923780...
# Best epsilon: 1.2584989506418272, Minimum GWD: 0.870
# Processing matrix pair 14/923780...
# Best epsilon: 1.2584989506418272, Minimum GWD: 0.838
# Processing matrix pair 15/923780...
# Best epsilon: 0.6313850355589193, Minimum GWD: 0.582
# Processing matrix pair 16/923780...
# Best epsilon: 1.2584989506418272, Minimum GWD: 0.863
# Processing matrix pair 17/923780...
# Best epsilon: 0.15891948094037048, Minimum GWD: 1.241
# Processing matrix pair 18/923780...
# Best epsilon: 0.8914019321842716, Minimum GWD: 0.701
# Processing matrix pair 19/923780...
# Best epsilon: 0.447213595499958, Minimum GWD: 0.559
# Processing matrix pair 20/923780...
# Best epsilon: 1.2584989506418272, Minimum GWD: 1.064
# Processing matrix pair 21/923780...
# Best epsilon: 0.6313850355589193, Minimum GWD: 0.856
# Processing matrix pair 22/923780...
# Best epsilon: 1.2584989506418272, Minimum GWD: 1.437
# Processing matrix pair 23/923780...
# Best epsilon: 1.2584989506418272, Minimum GWD: 0.965
# Processing matrix pair 24/923780...
# Best epsilon: 0.15891948094037048, Minimum GWD: 0.833
# Processing matrix pair 25/923780...
# Best epsilon: 0.6313850355589193, Minimum GWD: 0.869
# Processing matrix pair 26/923780...
# Best epsilon: 0.07972941262554757, Minimum GWD: 1.077
# Processing matrix pair 27/923780...
# Best epsilon: 0.31676392175331586, Minimum GWD: 1.222
# Processing matrix pair 28/923780...
# Best epsilon: 0.6313850355589193, Minimum GWD: 1.197
# Processing matrix pair 29/923780...
# Best epsilon: 0.8914019321842716, Minimum GWD: 1.262
# Processing matrix pair 30/923780...
# Best epsilon: 0.6313850355589193, Minimum GWD: 0.510
# Processing matrix pair 31/923780...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 compute_GWOT_for_all_pairs(grouping_averaged_allcombination_similarity_distance, epsilons)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Codes/GWOT_colorprefrencequalia/utilityFunctions_GWOT.py:105, in compute_GWOT_for_all_pairs(matrix_pairs, epsilons)
#     103 print(f"\nProcessing matrix pair {idx + 1}/{len(matrix_pairs)}...")
#     104 try:
# --> 105     OT_plan, gwds, matching_rates = GWD_and_plot(matrix1, matrix2, epsilons)
#     106     results.append((OT_plan, gwds, matching_rates))
#     107 except ValueError as e:
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Codes/GWOT_colorprefrencequalia/utilityFunctions_GWOT.py:47, in GWD_and_plot(matrix1, matrix2, epsilons)
#      44 valid_epsilons = []
#      46 for epsilon in epsilons:
# ---> 47     OT, gw_log = ot.gromov.entropic_gromov_wasserstein(
#      48         C1=matrix1, C2=matrix2, epsilon=epsilon, loss_fun="square_loss", log=True
#      49     )  # optimization
#      51     # Check if the transportation matrix is all zeros
#      52     if not OT.any():
#
# File /opt/anaconda3/envs/colorpreferencequalia/lib/python3.12/site-packages/ot/gromov/_bregman.py:199, in entropic_gromov_wasserstein(C1, C2, p, q, loss_fun, epsilon, symmetric, G0, max_iter, tol, solver, warmstart, verbose, log, **kwargs)
#     196     nu = epsilon * nx.log(loginn['v'])
#     198 else:
# --> 199     T = sinkhorn(p, q, tens, epsilon, method='sinkhorn', **kwargs)
#     201 if cpt % 10 == 0:
#     202     # we can speed up the process by checking for the error only all
#     203     # the 10th iterations
#     204     err = nx.norm(T - Tprev)
#
# File /opt/anaconda3/envs/colorpreferencequalia/lib/python3.12/site-packages/ot/bregman/_sinkhorn.py:154, in sinkhorn(a, b, M, reg, method, numItermax, stopThr, verbose, log, warn, warmstart, **kwargs)
#      24 r"""
#      25 Solve the entropic regularization optimal transport problem and return the OT matrix
#      26
#    (...)
#     150
#     151 """
#     153 if method.lower() == 'sinkhorn':
# --> 154     return sinkhorn_knopp(a, b, M, reg, numItermax=numItermax,
#     155                           stopThr=stopThr, verbose=verbose, log=log,
#     156                           warn=warn, warmstart=warmstart,
#     157                           **kwargs)
#     158 elif method.lower() == 'sinkhorn_log':
#     159     return sinkhorn_log(a, b, M, reg, numItermax=numItermax,
#     160                         stopThr=stopThr, verbose=verbose, log=log,
#     161                         warn=warn, warmstart=warmstart,
#     162                         **kwargs)
#
# File /opt/anaconda3/envs/colorpreferencequalia/lib/python3.12/site-packages/ot/bregman/_sinkhorn.py:502, in sinkhorn_knopp(a, b, M, reg, numItermax, stopThr, verbose, log, warn, warmstart, **kwargs)
#     498 v = b / KtransposeU
#     499 u = 1. / nx.dot(Kp, v)
#     501 if (nx.any(KtransposeU == 0)
# --> 502         or nx.any(nx.isnan(u)) or nx.any(nx.isnan(v))
#     503         or nx.any(nx.isinf(u)) or nx.any(nx.isinf(v))):
#     504     # we have reached the machine precision
#     505     # come back to previous solution and quit loop
#     506     warnings.warn('Warning: numerical errors at iteration %d' % ii)
#     507     u = uprev
#
# File /opt/anaconda3/envs/colorpreferencequalia/lib/python3.12/site-packages/ot/backend.py:1165, in NumpyBackend.any(self, a)
#    1164 def any(self, a):
# -> 1165     return np.any(a)
#
# KeyboardInterrupt:
